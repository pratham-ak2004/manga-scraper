# %%
# !sudo apt-get install xvfb
# !pip install bs4 selenium pyvirtualdisplay PyPDF2 requests pillow
# !pip install playwright bs4 pillow requests pypdf2
# !playwright install
# !playwright install-deps

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from pyvirtualdisplay import Display
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

from PIL import Image
import requests
import time
from io import BytesIO
from PyPDF2 import PdfMerger
import os
import json

# %%
driver = webdriver.Chrome()

# %%
url = "https://weebcentral.com/series/01J76XY7FQY59WRK2YWX5T4E5N/Vinland-Saga"
anime_name = "Vinland Saga"
json_path = f"../json/{anime_name.lower().replace(' ', '_')}_chapters.json"

# %%
driver.get(url)
button = driver.find_element(By.CSS_SELECTOR, 'button[hx-target="#chapter-list"]')
button.click()

time.sleep(5)

# %%
html_content = driver.page_source
soup = BeautifulSoup(html_content, 'html.parser')

# %%
chapters_map = {}

for chapter in reversed(soup.find(id="chapter-list").find_all("a")):
    link = chapter['href']
    if not (link.startswith("https://weebcentral.com/chapters")):
        continue

    name = chapter.find_all("span")[2].text.strip()
    chapters_map[name] = {
        "link": link,
        "images": []
    }

# %%
with open(json_path, "w", encoding="utf-8") as f:
    json.dump(chapters_map, f, ensure_ascii=False, indent=2)

# %%
def get_image_links(driver, chapter_link):
    driver.get(chapter_link)
    time.sleep(5)  # Wait for the page to load completely
    html_content = driver.page_source
    soup = BeautifulSoup(html_content, 'html.parser')
    
    title = soup.find("title").text.split(" | ")
    name, chapter = title[1], title[0].split()[1]

    image_section = soup.select_one('section[hx-include="[name=\'reading_style\']"]')
    image_tags = image_section.find_all("img")
    image_links = [img["src"] for img in image_tags]
    print(f"Found {len(image_links)} images for {name} - {chapter}")

    return name, chapter, image_links

# %%
try:
    with open(json_path, "r", encoding="utf-8") as f:
        chapters_map = json.load(f)

        for chapter_name, chapter_info in chapters_map.items():
            chapter_link = chapter_info["link"]
            if len(chapter_info["images"]) > 0:
                print(f"Skipping {chapter_name}, already has {len(chapter_info['images'])} images.")
                continue
            name, chapter, image_links = get_image_links(driver, chapter_link)
            chapters_map[chapter_name]["images"] = image_links

finally:
    with open(json_path, "w", encoding="utf-8") as f:
        json.dump(chapters_map, f, ensure_ascii=False, indent=2)
# Out:
# Skipping Chapter 1, already has 88 images.
# Skipping Chapter 2, already has 42 images.
# Skipping Chapter 3, already has 37 images.
# Skipping Chapter 4, already has 26 images.
# Skipping Chapter 5, already has 25 images.
# Skipping Chapter 6, already has 23 images.
# Skipping Chapter 7, already has 20 images.
# Skipping Chapter 8, already has 21 images.
# Skipping Chapter 9, already has 20 images.
# Skipping Chapter 10, already has 20 images.
# Skipping Chapter 11, already has 20 images.
# Skipping Chapter 12, already has 20 images.
# Skipping Chapter 13, already has 19 images.
# Skipping Chapter 14, already has 19 images.
# Skipping Chapter 15, already has 19 images.
# Skipping Chapter 16, already has 41 images.
# Skipping Chapter 17, already has 49 images.
# Skipping Chapter 18, already has 39 images.
# Skipping Chapter 19, already has 39 images.
# Skipping Chapter 20, already has 38 images.
# Skipping Chapter 21, already has 34 images.
# Skipping Chapter 21.5, already has 17 images.
# Skipping Chapter 22, already has 36 images.
# Skipping Chapter 23, already has 26 images.
# Skipping Chapter 24, already has 31 images.
# Skipping Chapter 25, already has 22 images.
# Skipping Chapter 26, already has 32 images.
# Skipping Chapter 27, already has 12 images.
# Skipping Chapter 28, already has 59 images.
# Skipping Chapter 29, already has 35 images.
# Skipping Chapter 30, already has 40 images.
# Skipping Chapter 31, already has 38 images.
# Skipping Chapter 32, already has 19 images.
# Skipping Chapter 33, already has 31 images.
# Skipping Chapter 34, already has 20 images.
# Skipping Chapter 35, already has 25 images.
# Skipping Chapter 36, already has 29 images.
# Skipping Chapter 37, already has 39 images.
# Skipping Chapter 38, already has 10 images.
# Skipping Chapter 39, already has 32 images.
# Skipping Chapter 40, already has 34 images.
# Skipping Chapter 41, already has 34 images.
# Skipping Chapter 42, already has 65 images.
# Skipping Chapter 43, already has 33 images.
# Skipping Chapter 44, already has 26 images.
# Skipping Chapter 45, already has 42 images.
# Skipping Chapter 46, already has 24 images.
# Skipping Chapter 47, already has 30 images.
# Skipping Chapter 48, already has 28 images.
# Skipping Chapter 49, already has 29 images.
# Skipping Chapter 50, already has 16 images.
# Skipping Chapter 51, already has 28 images.
# Skipping Chapter 52, already has 33 images.
# Skipping Chapter 53, already has 23 images.
# Skipping Chapter 54, already has 35 images.
# Skipping Chapter 55, already has 32 images.
# Skipping Chapter 56, already has 50 images.
# Skipping Chapter 57, already has 44 images.
# Skipping Chapter 58, already has 24 images.
# Skipping Chapter 59, already has 32 images.
# Skipping Chapter 60, already has 24 images.
# Skipping Chapter 61, already has 23 images.
# Skipping Chapter 62, already has 21 images.
# Skipping Chapter 63, already has 20 images.
# Skipping Chapter 64, already has 20 images.
# Skipping Chapter 65, already has 32 images.
# Skipping Chapter 66, already has 22 images.
# Skipping Chapter 67, already has 32 images.
# Skipping Chapter 68, already has 34 images.
# Skipping Chapter 69, already has 33 images.
# Skipping Chapter 70, already has 25 images.
# Skipping Chapter 71, already has 57 images.
# Skipping Chapter 72, already has 36 images.
# Skipping Chapter 73, already has 22 images.
# Skipping Chapter 74, already has 22 images.
# Skipping Chapter 75, already has 30 images.
# Skipping Chapter 76, already has 24 images.
# Skipping Chapter 77, already has 30 images.
# Skipping Chapter 78, already has 31 images.
# Skipping Chapter 79, already has 22 images.
# Skipping Chapter 80, already has 20 images.
# Skipping Chapter 81, already has 24 images.
# Skipping Chapter 82, already has 22 images.
# Skipping Chapter 83, already has 32 images.
# Skipping Chapter 84, already has 22 images.
# Skipping Chapter 85, already has 20 images.
# Skipping Chapter 86, already has 41 images.
# Skipping Chapter 87, already has 33 images.
# Skipping Chapter 88, already has 26 images.
# Skipping Chapter 89, already has 16 images.
# Skipping Chapter 90, already has 22 images.
# Skipping Chapter 91, already has 24 images.
# Skipping Chapter 92, already has 36 images.
# Skipping Chapter 93, already has 39 images.
# Skipping Chapter 94, already has 34 images.
# Skipping Chapter 95, already has 26 images.
# Skipping Chapter 96, already has 30 images.
# Skipping Chapter 97, already has 28 images.
# Skipping Chapter 98, already has 28 images.
# Skipping Chapter 99, already has 20 images.
# Skipping Chapter 100, already has 39 images.
# Skipping Chapter 101, already has 31 images.
# Skipping Chapter 102, already has 24 images.
# Skipping Chapter 103, already has 32 images.
# Skipping Chapter 104, already has 22 images.
# Skipping Chapter 105, already has 24 images.
# Skipping Chapter 106, already has 28 images.
# Skipping Chapter 107, already has 37 images.
# Skipping Chapter 108, already has 26 images.
# Skipping Chapter 109, already has 16 images.
# Skipping Chapter 110, already has 28 images.
# Skipping Chapter 111, already has 24 images.
# Skipping Chapter 112, already has 26 images.
# Skipping Chapter 113, already has 14 images.
# Skipping Chapter 114, already has 34 images.
# Skipping Chapter 115, already has 28 images.
# Skipping Chapter 116, already has 27 images.
# Skipping Chapter 117, already has 28 images.
# Skipping Chapter 118, already has 26 images.
# Skipping Chapter 119, already has 30 images.
# Skipping Chapter 120, already has 30 images.
# Skipping Chapter 121, already has 24 images.
# Skipping Chapter 122, already has 32 images.
# Skipping Chapter 123, already has 23 images.
# Skipping Chapter 124, already has 20 images.
# Skipping Chapter 125, already has 27 images.
# Skipping Chapter 126, already has 28 images.
# Skipping Chapter 127, already has 28 images.
# Skipping Chapter 128, already has 26 images.
# Skipping Chapter 129, already has 42 images.
# Skipping Chapter 130, already has 30 images.
# Skipping Chapter 131, already has 22 images.
# Skipping Chapter 132, already has 23 images.
# Skipping Chapter 133, already has 24 images.
# Skipping Chapter 134, already has 22 images.
# Skipping Chapter 135, already has 32 images.
# Skipping Chapter 136, already has 30 images.
# Skipping Chapter 136.5, already has 13 images.
# Skipping Chapter 137, already has 20 images.
# Skipping Chapter 138, already has 18 images.
# Skipping Chapter 139, already has 20 images.
# Skipping Chapter 140, already has 30 images.
# Skipping Chapter 141, already has 22 images.
# Skipping Chapter 142, already has 27 images.
# Skipping Chapter 143, already has 28 images.
# Skipping Chapter 144, already has 38 images.
# Skipping Chapter 145, already has 31 images.
# Skipping Chapter 146, already has 18 images.
# Skipping Chapter 147, already has 22 images.
# Skipping Chapter 148, already has 26 images.
# Skipping Chapter 149, already has 26 images.
# Skipping Chapter 150, already has 28 images.
# Skipping Chapter 151, already has 20 images.
# Skipping Chapter 152, already has 24 images.
# Skipping Chapter 153, already has 23 images.
# Skipping Chapter 154, already has 12 images.
# Skipping Chapter 155, already has 25 images.
# Skipping Chapter 156, already has 26 images.
# Skipping Chapter 157, already has 22 images.
# Skipping Chapter 158, already has 22 images.
# Skipping Chapter 159, already has 30 images.
# Skipping Chapter 160, already has 34 images.
# Skipping Chapter 161, already has 27 images.
# Skipping Chapter 162, already has 22 images.
# Skipping Chapter 163, already has 22 images.
# Skipping Chapter 164, already has 22 images.
# Skipping Chapter 165, already has 20 images.
# Skipping Chapter 166, already has 33 images.
# Skipping Chapter 167, already has 23 images.
# Skipping Chapter 168, already has 22 images.
# Skipping Chapter 169, already has 24 images.
# Skipping Chapter 170, already has 20 images.
# Skipping Chapter 171, already has 18 images.
# Skipping Chapter 172, already has 24 images.
# Skipping Chapter 173, already has 24 images.
# Skipping Chapter 174, already has 18 images.
# Skipping Chapter 175, already has 23 images.
# Skipping Chapter 175.5, already has 21 images.
# Skipping Chapter 176, already has 23 images.
# Skipping Chapter 177, already has 24 images.
# Skipping Chapter 178, already has 21 images.
# Skipping Chapter 179, already has 25 images.
# Skipping Chapter 180, already has 24 images.
# Skipping Chapter 181, already has 24 images.
# Skipping Chapter 182, already has 16 images.
# Skipping Chapter 183, already has 29 images.
# Skipping Chapter 184, already has 19 images.
# Skipping Chapter 185, already has 22 images.
# Skipping Chapter 186, already has 22 images.
# Skipping Chapter 187, already has 20 images.
# Skipping Chapter 188, already has 22 images.
# Skipping Chapter 189, already has 27 images.
# Skipping Chapter 190, already has 22 images.
# Skipping Chapter 191, already has 39 images.
# Skipping Chapter 192, already has 26 images.
# Skipping Chapter 193, already has 22 images.
# Skipping Chapter 194, already has 18 images.
# Skipping Chapter 195, already has 24 images.
# Skipping Chapter 196, already has 20 images.
# Skipping Chapter 197, already has 16 images.
# Skipping Chapter 198, already has 18 images.
# Skipping Chapter 199, already has 24 images.
# Skipping Chapter 200, already has 20 images.
# Skipping Chapter 201, already has 9 images.
# Skipping Chapter 202, already has 26 images.
# Skipping Chapter 203, already has 26 images.
# Skipping Chapter 204, already has 26 images.
# Skipping Chapter 205, already has 24 images.
# Skipping Chapter 206, already has 26 images.
# Skipping Chapter 207, already has 24 images.
# Skipping Chapter 208, already has 17 images.
# Skipping Chapter 209, already has 22 images.
# Skipping Chapter 210, already has 23 images.
# Skipping Chapter 211, already has 23 images.
# Skipping Chapter 212, already has 25 images.
# Skipping Chapter 213, already has 26 images.
# Skipping Chapter 214, already has 19 images.
# Skipping Chapter 215, already has 19 images.
# Skipping Chapter 216, already has 24 images.
# Skipping Chapter 217, already has 37 images.
# Skipping Chapter 218, already has 29 images.
# Skipping Chapter 219, already has 27 images.
# Skipping Chapter 220, already has 30 images.

# %%
with open(json_path, "w", encoding="utf-8") as f:
    json.dump(chapters_map, f, ensure_ascii=False, indent=2)

# %%
def download_images(payload):
    res = requests.post("http://localhost:8080/download", json=payload)
    print(res.status_code)

# %%
with open(json_path, "r", encoding="utf-8") as f:
    chapters_map = json.load(f)

    for chapter_name, chapter_info in chapters_map.items():
        print("Downloading images for chapter:", chapter_name)
        image_links = chapter_info["images"]
        if len(image_links) > 0:
            payload = {
                "folder": f"{anime_name}/{chapter_name.replace(' ', '_').replace('.', '_')}",
                "image_links": image_links
            }
            download_images(payload)
# Out:
# Downloading images for chapter: Chapter 1
# 202
# Downloading images for chapter: Chapter 2
# 202
# Downloading images for chapter: Chapter 3
# 202
# Downloading images for chapter: Chapter 4
# 202
# Downloading images for chapter: Chapter 5
# 202
# Downloading images for chapter: Chapter 6
# 202
# Downloading images for chapter: Chapter 7
# 202
# Downloading images for chapter: Chapter 8
# 202
# Downloading images for chapter: Chapter 9
# 202
# Downloading images for chapter: Chapter 10
# 202
# Downloading images for chapter: Chapter 11
# 202
# Downloading images for chapter: Chapter 12
# 202
# Downloading images for chapter: Chapter 13
# 202
# Downloading images for chapter: Chapter 14
# 202
# Downloading images for chapter: Chapter 15
# 202
# Downloading images for chapter: Chapter 16
# 202
# Downloading images for chapter: Chapter 17
# 202
# Downloading images for chapter: Chapter 18
# 202
# Downloading images for chapter: Chapter 19
# 202
# Downloading images for chapter: Chapter 20
# 202
# Downloading images for chapter: Chapter 21
# 202
# Downloading images for chapter: Chapter 21.5
# 202
# Downloading images for chapter: Chapter 22
# 202
# Downloading images for chapter: Chapter 23
# 202
# Downloading images for chapter: Chapter 168
# 202
# Downloading images for chapter: Chapter 169
# 202
# Downloading images for chapter: Chapter 170
# 202
# Downloading images for chapter: Chapter 171
# 202
# Downloading images for chapter: Chapter 172
# 202
# Downloading images for chapter: Chapter 173
# 202
# Downloading images for chapter: Chapter 174
# 202
# Downloading images for chapter: Chapter 175
# 202
# Downloading images for chapter: Chapter 175.5
# 202
# Downloading images for chapter: Chapter 176
# 202
# Downloading images for chapter: Chapter 177
# 202
# Downloading images for chapter: Chapter 178
# 202
# Downloading images for chapter: Chapter 179
# 202
# Downloading images for chapter: Chapter 180
# 202
# Downloading images for chapter: Chapter 181
# 202
# Downloading images for chapter: Chapter 182
# 202
# Downloading images for chapter: Chapter 183
# 202
# Downloading images for chapter: Chapter 184
# 202
# Downloading images for chapter: Chapter 185
# 202
# Downloading images for chapter: Chapter 186
# 202
# Downloading images for chapter: Chapter 187
# 202
# Downloading images for chapter: Chapter 188
# 202
# Downloading images for chapter: Chapter 189
# 202
# Downloading images for chapter: Chapter 190
# 202
# Downloading images for chapter: Chapter 191
# 202
# Downloading images for chapter: Chapter 192
# 202
# Downloading images for chapter: Chapter 193
# 202
# Downloading images for chapter: Chapter 194
# 202
# Downloading images for chapter: Chapter 195
# 202
# Downloading images for chapter: Chapter 196
# 202
# Downloading images for chapter: Chapter 197
# 202
# Downloading images for chapter: Chapter 198
# 202
# Downloading images for chapter: Chapter 199
# 202
# Downloading images for chapter: Chapter 200
# 202
# Downloading images for chapter: Chapter 201
# 202
# Downloading images for chapter: Chapter 202
# 202
# Downloading images for chapter: Chapter 203
# 202
# Downloading images for chapter: Chapter 204
# 202
# Downloading images for chapter: Chapter 205
# 202
# Downloading images for chapter: Chapter 206
# 202
# Downloading images for chapter: Chapter 207
# 202
# Downloading images for chapter: Chapter 208
# 202
# Downloading images for chapter: Chapter 209
# 202
# Downloading images for chapter: Chapter 210
# 202
# Downloading images for chapter: Chapter 211
# 202
# Downloading images for chapter: Chapter 212
# 202
# Downloading images for chapter: Chapter 213
# 202
# Downloading images for chapter: Chapter 214
# 202
# Downloading images for chapter: Chapter 215
# 202
# Downloading images for chapter: Chapter 216
# 202
# Downloading images for chapter: Chapter 217
# 202
# Downloading images for chapter: Chapter 218
# 202
# Downloading images for chapter: Chapter 219
# 202
# Downloading images for chapter: Chapter 220
# 202

# %%
images = []

for chapter_folder in sorted(os.listdir(anime_name)):
    chapter_path = os.path.join(anime_name, chapter_folder)
    
    if os.path.isdir(chapter_path):
        for image_file in sorted(os.listdir(chapter_path)):
            image_path = os.path.join(chapter_path, image_file)
            images.append(Image.open(image_path).convert("RGB"))

# %%
if images:
    pdf_path = f"../pdfs/{anime_name}.pdf"
    images[0].save(pdf_path, save_all=True, append_images=images[1:])
    print(f"Saved PDF: {pdf_path}")

# %%
driver.quit()

# %%
import json

with open(json_path, "r", encoding="utf-8") as f:
    chapters_map = json.load(f)
    total_images = 0
    
    for chapter_name, chapter_info in chapters_map.items():
        # print(f"{chapter_name}: {len(chapter_info['images'])} images")
        total_images += len(chapter_info['images'])
        
    print(f"Total images: {total_images}")
    print(f"Total chapters: {len(chapters_map)}")
